# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#load_dataset
phool=sns.load_dataset("iris")

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#draw line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.show()

# %%
#Adding titles
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.show()

# %%
#Adding limits
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.xlim(2)
plt.ylim(1)

plt.show()

# %% [markdown]
# # set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
sns.set_style(style=None,rc=None)
sns.set_style("dark")
plt.show()

# %%
# size of figure
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.figure(figsize=(10,10))
plt.show()

# %% [markdown]
# ## barplot

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load_dataset
phool=sns.load_dataset("iris")
phool

#draw bar plot
sns.barplot(x="species",y="sepal_width",data=phool)
plt.show()

# %%
#load_dataset
phool=sns.load_dataset("iris")
phool

#draw bar plot
sns.barplot(x="species",y="petal_length",data=phool)
plt.show()

# %%
#load_dataset
kashti=sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="who",y="alone",hue="who",data=kashti)
plt.show()

# %%
# change location of male and female
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="who",y="alone",hue="who",data=kashti, order=["woman","man"])
plt.show()

# %%
#Colour changing
# change location of male and female
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="who",y="alone",hue="who",data=kashti, order=["woman","man"],color="brown")
plt.show()

# %%
# Removing error bars and palette(colours)
#Colour changing
# change location of male and female
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="who",y="alone",hue="who",data=kashti, order=["woman","man"],color="brown",ci=None,palette="pastel")
plt.show()

# %%
#estimator of median
from numpy import median
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="class",y="fare",hue="who",data=kashti,estimator=median,saturation=0.1)
plt.show()

# %% [markdown]
# ## Horizontal graph

# %%
#estimator of median
from numpy import median
import seaborn as sns
import matplotlib.pyplot as plt
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="fare",y="class",hue="who",data=kashti,estimator=median,saturation=1)
plt.show()

# %% [markdown]
# ## colour of error and bars

# %%
#estimator of median
from numpy import median
import seaborn as sns
import matplotlib.pyplot as plt
#load_dataset
kashti=sns.load_dataset("titanic")
kashti

#draw bar plot
sns.barplot(x="class",y="fare",hue="who",data=kashti,estimator=median,saturation=0.1,
           linewidth=3,facecolor=(1,0.7,1,0),errcolor=".5",edgecolor="0")
plt.show()
